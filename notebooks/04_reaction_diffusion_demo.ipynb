# %% [markdown]
# # Reaction Diffusion Demo
#
# Run the 1D PET film enzyme-diffusion package example and save spatial outputs.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
SRC = ROOT / "src"
EXAMPLES = ROOT / "examples"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))
if str(EXAMPLES) not in sys.path:
    sys.path.insert(0, str(EXAMPLES))

import fungal_model
import stage12_06_spatial_pet_film as spatial_demo
spatial_demo.run(ROOT / "outputs" / "notebook_04_reaction_diffusion")
