# %% [markdown]
# # Generic Surface Hydrolysis Demo
#
# Use the same generic surface-catalysis components for two toy solid substrates.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from fungal_model import AccessibleSitePool, AccessibleSurfaceAreaModel, LangmuirAdsorptionModel, ProductReleaseMap, SurfaceCatalysisModel, SurfaceCatalysisProcess
from fungal_model.core.units import Q_

# %%
shared_adsorption = LangmuirAdsorptionModel("K_ads", "mole / liter", "Toy surface demo adsorption model.")
shared_catalysis = SurfaceCatalysisModel("k_surface", "kilogram / second", "Toy surface demo catalysis model.")

cellulose_process = SurfaceCatalysisProcess(
    name="toy cellulose surface cleavage",
    substrate_state="cellulose_mass",
    enzyme_state="E",
    substrate_units="kilogram",
    enzyme_units="mole / liter",
    accessible_site_pool=AccessibleSitePool("cellulose accessible surface", "beta-1,4-glycosidic"),
    accessible_surface_model=AccessibleSurfaceAreaModel.from_quantity(name="cellulose area", area=Q_(0.5, "meter ** 2")),
    adsorption_model=shared_adsorption,
    catalytic_model=shared_catalysis,
    product_release_map=ProductReleaseMap.one_to_one(substrate_state="cellulose_mass", product_state="sugar_equivalent"),
)

chitin_process = SurfaceCatalysisProcess(
    name="toy chitin surface cleavage",
    substrate_state="chitin_mass",
    enzyme_state="E",
    substrate_units="kilogram",
    enzyme_units="mole / liter",
    accessible_site_pool=AccessibleSitePool("chitin accessible surface", "beta-1,4-glycosidic"),
    accessible_surface_model=AccessibleSurfaceAreaModel.from_quantity(name="chitin area", area=Q_(0.25, "meter ** 2")),
    adsorption_model=shared_adsorption,
    catalytic_model=shared_catalysis,
    product_release_map=ProductReleaseMap.one_to_one(substrate_state="chitin_mass", product_state="oligomer_equivalent"),
)

[cellulose_process.to_dict(), chitin_process.to_dict()]
# Out:
# [{'name': 'toy cellulose surface cleavage',
#   'process_type': 'surface_catalysis',
#   'required_state_variables': [{'name': 'cellulose_mass',
#     'units': 'kilogram',
#     'description': '',
#     'role': 'solid_substrate'},
#    {'name': 'E',
#     'units': 'mole / liter',
#     'description': '',
#     'role': 'free_catalyst'}],
#   'changed_state_variables': [{'name': 'sugar_equivalent',
#     'units': 'kilogram',
#     'description': '',
#     'role': 'state'},
#    {'name': 'cellulose_mass',
#     'units': 'kilogram',
#     'description': '',
#     'role': 'state'}],
#   'required_parameters': [{'symbol': 'K_ads',
#     'units': '1 / (mole / liter)',
#     'name': 'Langmuir adsorption equilibrium constant',
#     'description': '',
#     'required': True},
#    {'symbol': 'k_surface',
#     'units': 'kilogram / second / meter ** 2',
#     'name': 'surface catalysis rate constant',
#     'description': '',
#     'required': True}],
#   'assumptions': [{'name': 'generic equilibrium surface catalysis',
#     'description': 'A surface-active catalyst binds according to an explicit coverage model, and bond-cleavage rate scales with occupied accessible surface area.',
#     'justification': 'Surface-limited solid-substrate models need a generic mechanism that is independent of any named substrate such as PET.',
#     'known_limitations': 'Does not model dynamic adsorption/desorption state variables, surface renewal, product inhibition, pore accessibility, or changing morphology.',
#     'source': 'Generic surface adsorption and catalysis modelling assumption.'},
#    {'name': 'equilibrium Langmuir adsorption',
#     'description': 'Free catalyst/enzyme coverage is theta = K_ads * E / (1 + K_ads * E).',
#     'justification': 'A small equilibrium coverage model is useful before dynamic binding states are added.',
#     'known_limitations': 'No explicit bound enzyme state, desorption dynamics, or site saturation dynamics.',
#     'source': 'Toy surface demo adsorption model.'},
#    {'name': 'surface-proportional catalysis',
#     'description': 'Catalytic rate is proportional to occupied accessible surface area.',
#     'justification': 'A minimal surface-rate model is needed before detailed erosion and surface renewal.',
#     'known_limitations': 'Does not represent product inhibition, surface ageing, or changing accessible area.',
#     'source': 'Toy surface demo catalysis model.'}],
#   'validity': {'description': 'Generic equilibrium-adsorption surface catalysis process.',
#    'labels': ['surface', 'heterogeneous', 'bond_cleavage'],
#    'limitations': ['Accessible surface area is supplied by an explicit model and is not evolved dynamically.']},
#   'failure_modes': ['missing accessible surface area',
#    'missing adsorption parameter',
#    'missing surface catalytic parameter',
#    'incompatible catalyst/substrate state units'],
#   'source': 'Generic surface catalysis process.',
#   'notes': '',
#   'accessible_site_pool': {'name': 'cellulose accessible surface',
#    'bond_type': 'beta-1,4-glycosidic',
#    'units': 'meter ** 2',
#    'notes': ''},
#   'accessible_surface_model': {'name': 'cellulose area',
#    'area': {'value': 0.5, 'units': 'meter ** 2'},
#    'parameter_symbol': None,
#    'assumptions': [],
#    'notes': ''},
#   'adsorption_model': {'adsorption_symbol': 'K_ads',
#    'enzyme_units': 'mole / liter',
#    'source': 'Toy surface demo adsorption model.',
#    'notes': ''},
#   'catalytic_model': {'surface_rate_symbol': 'k_surface',
#    'rate_units': 'kilogram / second',
#    'source': 'Toy surface demo catalysis model.',
#    'notes': ''},
#   'product_release_map': {'reactants': {'cellulose_mass': 1.0},
#    'products': {'sugar_equivalent': 1.0},
#    'notes': ''}},
#  {'name': 'toy chitin surface cleavage',
#   'process_type': 'surface_catalysis',
#   'required_state_variables': [{'name': 'chitin_mass',
#     'units': 'kilogram',
#     'description': '',
#     'role': 'solid_substrate'},
#    {'name': 'E',
#     'units': 'mole / liter',
#     'description': '',
#     'role': 'free_catalyst'}],
#   'changed_state_variables': [{'name': 'oligomer_equivalent',
#     'units': 'kilogram',
#     'description': '',
#     'role': 'state'},
#    {'name': 'chitin_mass',
#     'units': 'kilogram',
#     'description': '',
#     'role': 'state'}],
#   'required_parameters': [{'symbol': 'K_ads',
#     'units': '1 / (mole / liter)',
#     'name': 'Langmuir adsorption equilibrium constant',
#     'description': '',
#     'required': True},
#    {'symbol': 'k_surface',
#     'units': 'kilogram / second / meter ** 2',
#     'name': 'surface catalysis rate constant',
#     'description': '',
#     'required': True}],
#   'assumptions': [{'name': 'generic equilibrium surface catalysis',
#     'description': 'A surface-active catalyst binds according to an explicit coverage model, and bond-cleavage rate scales with occupied accessible surface area.',
#     'justification': 'Surface-limited solid-substrate models need a generic mechanism that is independent of any named substrate such as PET.',
#     'known_limitations': 'Does not model dynamic adsorption/desorption state variables, surface renewal, product inhibition, pore accessibility, or changing morphology.',
#     'source': 'Generic surface adsorption and catalysis modelling assumption.'},
#    {'name': 'equilibrium Langmuir adsorption',
#     'description': 'Free catalyst/enzyme coverage is theta = K_ads * E / (1 + K_ads * E).',
#     'justification': 'A small equilibrium coverage model is useful before dynamic binding states are added.',
#     'known_limitations': 'No explicit bound enzyme state, desorption dynamics, or site saturation dynamics.',
#     'source': 'Toy surface demo adsorption model.'},
#    {'name': 'surface-proportional catalysis',
#     'description': 'Catalytic rate is proportional to occupied accessible surface area.',
#     'justification': 'A minimal surface-rate model is needed before detailed erosion and surface renewal.',
#     'known_limitations': 'Does not represent product inhibition, surface ageing, or changing accessible area.',
#     'source': 'Toy surface demo catalysis model.'}],
#   'validity': {'description': 'Generic equilibrium-adsorption surface catalysis process.',
#    'labels': ['surface', 'heterogeneous', 'bond_cleavage'],
#    'limitations': ['Accessible surface area is supplied by an explicit model and is not evolved dynamically.']},
#   'failure_modes': ['missing accessible surface area',
#    'missing adsorption parameter',
#    'missing surface catalytic parameter',
#    'incompatible catalyst/substrate state units'],
#   'source': 'Generic surface catalysis process.',
#   'notes': '',
#   'accessible_site_pool': {'name': 'chitin accessible surface',
#    'bond_type': 'beta-1,4-glycosidic',
#    'units': 'meter ** 2',
#    'notes': ''},
#   'accessible_surface_model': {'name': 'chitin area',
#    'area': {'value': 0.25, 'units': 'meter ** 2'},
#    'parameter_symbol': None,
#    'assumptions': [],
#    'notes': ''},
#   'adsorption_model': {'adsorption_symbol': 'K_ads',
#    'enzyme_units': 'mole / liter',
#    'source': 'Toy surface demo adsorption model.',
#    'notes': ''},
#   'catalytic_model': {'surface_rate_symbol': 'k_surface',
#    'rate_units': 'kilogram / second',
#    'source': 'Toy surface demo catalysis model.',
#    'notes': ''},
#   'product_release_map': {'reactants': {'chitin_mass': 1.0},
#    'products': {'oligomer_equivalent': 1.0},
#    'notes': ''}}]
