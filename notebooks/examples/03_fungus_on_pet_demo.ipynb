# %% [markdown]
# # Fungus On PET Demo
#
# Use the existing package example modules for PET, enzyme secretion, enzyme decay, surface cleavage, product uptake, growth, and validation reports.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
SRC = ROOT / "src"
EXAMPLES = ROOT / "examples"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))
if str(EXAMPLES) not in sys.path:
    sys.path.insert(0, str(EXAMPLES))

import fungal_model
import stage12_05_fungal_growth_from_assimilable_products as pet_growth_demo
pet_growth_demo.run(ROOT / "outputs" / "notebook_03_fungus_on_pet")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 12
#       8 if str(EXAMPLES) not in sys.path:
#       9     sys.path.insert(0, str(EXAMPLES))
#      10
#      11 import fungal_model
# ---> 12 import stage12_05_fungal_growth_from_assimilable_products as pet_growth_demo
#      13 pet_growth_demo.run(ROOT / "outputs" / "notebook_03_fungus_on_pet")
#
# ModuleNotFoundError: No module named 'stage12_05_fungal_growth_from_assimilable_products'
